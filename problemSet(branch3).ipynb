# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = input()
if i.islower() == True:
    print(i.upper())
else:
    print(i.lower())
# Out:
# a
# A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = int(input())
if i >= 81 and i <= 100:
    print("A")
elif i >= 61 and i <= 80:
    print("B")
elif i >= 41 and i <= 60:
    print("C")
elif i >= 21 and i <= 40:
    print("D")
elif i >= 0 and i <= 20:
    print("E")
    
#문제- 해당 코드에선 200을 입력해도 E가 뜬다. elif i >= 0 and i <= 20 으로 코드를 짜면 에러가 뜨는데, 이에 대한 해결방법은?
# Out:
# 3
# E

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = input("입력: ")
List_i = i.split(" ")
if "달러" in List_i:
    print(round(float(1167*int(List_i[0])), 2), "원")
elif "엔" in List_i:
    print(1.096*int(List_i[0]), "원")
elif "유로" in List_i:
    print(1268*int(List_i[0]), "원")
elif "위안" in List_i:
    print(171*int(List_i[0]), "원")
 # 116700.00 과 같은 숫자 형식은 어떻게 구현?
# Out:
# 입력: 100 달러
# 116700.0 원

# %%
i = input("입력: ")
i.split(" ")
if "달러" in i:
    print(1167*int(i[0]), "원")
elif "엔" in i:
    print(1.096*int(i[0]), "원")
elif "유로" in i:
    print(1268*int(i[0]), "원")
elif "위안" in i:
    print(171*int(List_i[0]), "원")
# Out:
# 입력: 100 달러
# 1167 원

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input("imput number1: "))
b = int(input("imput number2: "))
c = int(input("imput number3: "))
List_1 = [a, b, c]
print(max(List_1))
# Out:
# imput number1: 10
# imput number2: 9
# imput number3: 20
# 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = input("우편번호: ")
if i[0:3] == '010' or i[0:3] =='011' or i[0:3] =='012':
    print("강북구")
elif i[0:3] == '013' or i[0:3] =='014' or i[0:3] =='015':
    print("도봉구")
elif i[0:3] == '016' or i[0:3] =='017' or i[0:3] =='018' or i[0:3] =='019':
    print("노원구")
#더 쉽게 나타낼 방법은?
# Out:
# 우편번호: 01678
# 노원구

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
J_1 = input("주민등록번호: ")
J_2 = J_1.split("-")[1]
# split 하고 나서 결과값은 list/str 형태
if J_2[0] == '1' or J_2[0] == '3':
    print("남자")
elif J_2[0] == '2' or J_2[0] == '4':
    print("여자")
# 왜 틀렸는지?
# Out:
# 주민등록번호: 821010-1635210
# 남자

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
J_num = input("주민등록번호: ")
a = int(J_num[0]) * 2
b = int(J_num[1]) * 3
c = int(J_num[2]) * 4
d = int(J_num[3]) * 5
e = int(J_num[4]) * 6
f = int(J_num[5]) * 7
g = int(J_num[7]) * 8
h = int(J_num[8]) * 9
i = int(J_num[9]) * 2
j = int(J_num[10]) * 3
k = int(J_num[11]) * 4
l = int(J_num[12]) * 5
Step_1 = (a + b + c + d + e + f + g + h + i + j + k + l) % 11
Step_2 = 11 - Step_1
if int(J_num[13]) == Step_2:
    print(J_num)
else:
    print("유효하지 않은 주민등록번호입니다.")
#왜 주민등록번호에 821010-1635214을 입력하면 "유효하지 않은 주민등록번호입니다" 라고 뜰까?
# Out:
# 주민등록번호: 821010-1635214
# 유효하지 않은 주민등록번호입니다.

# %% [markdown]
# ![image.png](attachment:image.png)
