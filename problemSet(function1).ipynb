# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def print_coin():
    B_coin = "비트코인"
    return B_coin

print(print_coin())
# Out:
# 비트코인

# %%
def print_coin():
    print("비트코인")

print_coin()
# 두 가지 케이스 다 '함수를 정의했다'고 표현 가능?
# 결과값은 똑같지만 문제의 출제의도에 맞는 정답은 무엇?
# Out:
# 비트코인

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def print_coin():
    B_coin = "비트코인"
    return B_coin
print(print_coin())
# Out:
# 비트코인

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def print_coin():
    B_coin = "비트코인"
    print(B_coin)

print_coin()*100
# Out:
# 비트코인
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17960/2370207106.py in <module>
#       3     print(B_coin)
#       4
# ----> 5 print_coin()*100
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def print_coins():
    for i in range(100):
        print("비트코인")

print_coins()
# Out:
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#hello 함수를 먼저 정의하지 않았다.
def hello():
    print("Hi")
hello()
# Out:
# Hi

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def message():
    print("A")
    print("B")
    
message()
# Out:
# A
# B

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("A")

def message():
    print("B")
    
print("C")
message()
# Out:
# A
# C
# B

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("A")
def message1():
    print("B")
print("C")
def message2():
    print("D")
message1()
print("E")
message2()
# Out:
# A
# C
# B
# E
# D

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def message1():
    print("A")
    
def message2():
    print("B")
    message1()
    
message2()
# Out:
# B
# A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def message1():
    print("A")
    
def message2():
    print("B")
    
def message3():
    for i in range (3) :
        message2()
        print("C")
    message1()
    
message3()
# Out:
# B
# C
# B
# C
# B
# C
# A
