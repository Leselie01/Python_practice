# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num_list = [100, 200, 300]
while True:
    if i in num_list <400:
        print(i + 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24688/3884761516.py in <module>
#       1 num_list = [100, 200, 300]
#       2 while True:
# ----> 3     if i in num_list <400:
#       4         print(i + 10)
#       5
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ["김밥", "라면", "튀김"]
for i in list:
    print("오늘의 메뉴: ", i)
# Out:
# 오늘의 메뉴:  김밥
# 오늘의 메뉴:  라면
# 오늘의 메뉴:  튀김

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ["SK하이닉스", "삼성전자", "LG전자"]
for i in list:
    print(len(i))
# Out:
# 6
# 4
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ['dog', 'cat', 'parrot']
for i in list:
    print(i, len(i))
# Out:
# dog 3
# cat 3
# parrot 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ['dog', 'cat', 'parrot']
for i in list:
    print(i[0])
# Out:
# d
# c
# p

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = [1, 2, 3]
for i in list:
    print("3 x", i)
#'숫자가 바인딩되어 있다' -> 일반적인 리스트랑은 다른건가?
# Out:
# 3 x 1
# 3 x 2
# 3 x 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = [1, 2, 3]
for i in list:
    a = 3 * i
    print("3 x", i, "=", a)
# 곱셈식의 형식을 일반화하여 나타낼 수 있는 방법은?
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ["가", "나", "다", "라"]
for i in list[1:]:
    print(i)
# Out:
# 나
# 다
# 라

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ["가", "나", "다", "라"]
for i in list[0::2]:
    print(i)
# Out:
# 가
# 다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ["가", "나", "다", "라"]
for i in list:
    print(list.reverse())
#왜 이렇게 나오지?
# Out:
# None
# None
# None
# None

# %%
list = ["가", "나", "다", "라"]
for i in list[::-1]:
    print (i)
# Out:
# 라
# 다
# 나
# 가
