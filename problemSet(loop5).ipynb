# %% [markdown]
# ![image.png](attachment:image.png)

# %%
price_list = [32100, 32150, 32000, 32500]
for i in price_list:
    print(i)
# Out:
# 32100
# 32150
# 32000
# 32500

# %%
price_list = [32100, 32150, 32000, 32500]
i = -1
while i < 5:
    i = i + 1
    if i == 4:
        break
    print (price_list[i])
# Out:
# 32100
# 32150
# 32000
# 32500

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
price_list = [32100, 32150, 32000, 32500]
for i in range(4):
    print(i, price_list[i])
# Out:
# 0 32100
# 1 32150
# 2 32000
# 3 32500

# %%
price_list = [32100, 32150, 32000, 32500]
i = 0
while i < 4:
    print(i, price_list[i])
    i = i + 1
# Out:
# 0 32100
# 1 32150
# 2 32000
# 3 32500

# %%
price_list = [32100, 32150, 32000, 32500]
data = enumerate(price_list)
for i, value in data:
    print(i, value)
# Out:
# 0 32100
# 1 32150
# 2 32000
# 3 32500

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
price_list = [32100, 32150, 32000, 32500]
data = enumerate(price_list)
for i, value in data:
    print(3 - i, value)
# Out:
# 3 32100
# 2 32150
# 1 32000
# 0 32500

# %%
price_list = [32100, 32150, 32000, 32500]
i = 4
while i > 0:
    i = i - 1
    print(i, price_list[3-i])
# Out:
# 3 32100
# 2 32150
# 1 32000
# 0 32500

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
price_list = [32100, 32150, 32000, 32500]
for i in range(1, 4):
    print(i * 10 + 90, price_list[i])
# Out:
# 100 32150
# 110 32000
# 120 32500

# %%
price_list = [32100, 32150, 32000, 32500]
i = 0
while i < 3:
    i = i + 1
    print(i * 10 + 90, price_list[i])
# Out:
# 100 32150
# 110 32000
# 120 32500

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_list = ["가", "나", "다", "라"]
for i in range(3):
    print(my_list[i], my_list[i+1])
# Out:
# 가 나
# 나 다
# 다 라

# %%
my_list = ["가", "나", "다", "라"]
i = -1
while i < 2:
    i = i + 1
    print(my_list[i], my_list[i+1])
# Out:
# 가 나
# 나 다
# 다 라

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_list = ["가", "나", "다", "라", "마"]
for i in range(3):
    print(my_list[i], my_list[i+1], my_list[i+2])
# Out:
# 가 나 다
# 나 다 라
# 다 라 마

# %%
my_list = ["가", "나", "다", "라", "마"]
i = -1
while i < 2:
    i = i + 1
    print(my_list[i], my_list[i+1], my_list[i+2])
# Out:
# 가 나 다
# 나 다 라
# 다 라 마

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_list = ["가", "나", "다", "라"]
i = 4
while i > 1:
    i = i - 1
    print(my_list[i], my_list[i-1])
# Out:
# 라 다
# 다 나
# 나 가

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_list = [100, 200, 400, 800]
for i in range(1, 4):
    print(my_list[i] - my_list[i-1])
# Out:
# 100
# 200
# 400

# %%
my_list = [100, 200, 400, 800]
i = 0
while i < 3:
    i = i + 1
    print(my_list[i] - my_list[i - 1])
# Out:
# 100
# 200
# 400

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_list = [100, 200, 400, 800, 1000, 1300]
for i in range(4):
    sum_list = my_list[i] + my_list[i+1] + my_list[i+2]
    print(sum_list/3)
# Out:
# 233.33333333333334
# 466.6666666666667
# 733.3333333333334
# 1033.3333333333333

# %%
my_list = [100, 200, 400, 800, 1000, 1300]
i = -1
while i < 3:
    i = i + 1
    sum_list = my_list[i] + my_list[i+1] + my_list[i+2]
    print(sum_list/3)
# Out:
# 233.33333333333334
# 466.6666666666667
# 733.3333333333334
# 1033.3333333333333

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
low_prices = [100, 200, 400, 800, 1000]
high_prices = [150, 300, 430, 880, 1000]
volatility = []
for i in range(5):
    fluc_dif = high_prices[i] - low_prices[i]
    volatility.append(fluc_dif)
print(volatility)
# Out:
# [50, 100, 30, 80, 0]

# %%
low_prices = [100, 200, 400, 800, 1000]
high_prices = [150, 300, 430, 880, 1000]
volatility = []
i = -1
while i < 4:
    i = i + 1
    fluc_dif = high_prices[i] - low_prices[i]
    volatility.append(fluc_dif)
print(volatility)
# Out:
# [50, 100, 30, 80, 0]
