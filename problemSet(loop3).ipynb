# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = [3, -20, -3, 44]
for i in list:
    if i < 0:
        print(i)
# Out:
# -20
# -3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = [3, 100, 23, 44]
for i in list:
    if i % 3 == 0:
        print(i)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = [13, 21, 12, 14, 30, 18]
for i in list:
    if i < 20 and i % 3 == 0:
        print(i)
# Out:
# 12
# 18

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ["I", "study", "python", "language", "!"]
for i in list:
    if len(i) > 3:
        print(i)
# Out:
# study
# python
# language

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ["A", "b", "c", "D"]
for i in list:
    if i.isupper() == True:
        print(i)
# Out:
# A
# D

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ["A", "b", "c", "D"]
for i in list:
    if i.islower() == True:
        print(i)
# Out:
# b
# c

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ['dog', 'cat', 'parrot']
for i in list:
    C = i[0]
    replace_list = C.replace(C, C.upper(), 1)
    print(i)
    
#모르겠음!!!
# Out:
# dog
# cat
# parrot

# %%
animal_list = ['dog', 'cat', 'parrot']
for i in range(len(animal_list)):
    i = i.replace(i[0], i[0].upper(), 1)
    animal_list[i] = "".join(i)
print(animal_list)

#숙제: 밑의 형식으로 바꿔보기!
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11576/278375801.py in <module>
#       1 animal_list = ['dog', 'cat', 'parrot']
#       2 for i in range(len(animal_list)):
# ----> 3     i = i.replace(i[0], i[0].upper(), 1)
#       4     animal_list[i] = "".join(i)
#       5 print(animal_list)
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
animal_list = ['dog', 'cat', 'parrot']
for i in range(len(animal_list)):
    C = list(animal_list[i])
    C[0] = C[0].upper()
    animal_list[i] = "".join(C)
for i in animal_list:
    print(i)
# Out:
# Dog
# Cat
# Parrot

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ['hello.py', 'ex01.py', 'intro.hwp']
for i in list:
    File = i.split(".")[0]
    print(File)
# Out:
# hello
# ex01
# intro

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ['intra.h', 'intra.c', 'define.h', 'run.py']
for i in list:
    S = i.split(".")[1]
    if S == 'h':
        print(i)
#왜 h를 str 처리? S[1] == h를 해도 될 것 같은데 안됨. 이유는? -> 변수취급
# Out:
# intra.h
# define.h

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = ['intra.h', 'intra.c', 'define.h', 'run.py']
for i in list:
    File_1 = i.split(".")[1]
    if File_1 == 'h' or File_1 == 'c':
        print(i)
# Out:
# intra.h
# intra.c
# define.h
